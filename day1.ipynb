# %% [markdown]
# DAT TYPES AND VARIABLES

# %%
first = "Hi"

# %%
first
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-271ac93c44ac> in <module>()
# ----> 1 first
#
# NameError: name 'first' is not defined

# %%
first = "hi"
first
# Out:
# 'hi'

# %%
sum = (23+2)/4
sum
sum = sum+10

# %%
sum
# Out:
# 16.25

# %% [markdown]
# LISTS

# %%
whole_numbers = [0,1,2,3,4,]

# %%
len(whole_numbers)
# Out:
# 5

# %%
names =["aravind", "mallesh", "sai"]

# %%
names
# Out:
# ['aravind', 'mallesh', 'sai']

# %%
names[2]
# Out:
# 'sai'

# %%
names[0]
# Out:
# 'aravind'

# %% [markdown]
# dictionary

# %%
menu = {
    "samosa" : 25,
    "dosa" : 40,
     "juice" : 35
}

# %%
menu["dosa"]
# Out:
# 40

# %% [markdown]
# OPERATORS

# %%
1+1
# Out:
# 2

# %%
5==5
# Out:
# True

# %%
5!=23
# Out:
# True

# %%
"ArAvind" == "aravind"
# Out:
# False

# %%
"ARAvind" == "ARAvind"
# Out:
# True

# %% [markdown]
# FUNCTIONS

# %%
def convert_to_fahrenheit(celsiusTemp):
    product = celsiusTemp * 1.8
    final = product + 32
    return final

# %%
convert_to_fahrenheit(50)
# Out:
# 122.0

# %%
# day 2

# %%
counter = 100
miles = 1000.0
name = "John"
print(counter)
print(miles)
print(name)
# Out:
# 100
# 1000.0
# John

# %%
# multiple assignment

# %%
a=b=c=1

# %%
d=e=f=50.3

# %%
g=h=i= "sample"

# %%
a
# Out:
# 1

# %%
e
# Out:
# 50.3

# %%
h
# Out:
# 'sample'

# %%
# eg : 2

# %%
aa,bb,cc=11,22,"adc"

# %%
aa
# Out:
# 11

# %%
cc
# Out:
# 'adc'

# %%
bb
# Out:
# 22

# %%
# PYTHON STRINGS

# %%
str='Hello World!'

# %%
print(str) #prints complete string
# Out:
# Hello World!

# %%
print (str[0]) #prinyts 1st character of the string
# Out:
# H

# %%
print(str[2:5]) #print char starting fronm 3rd to 5th
# Out:
# llo

# %%
print(str[2:]) #print starting from 3rd char
# Out:
# llo World!

# %%
print(str*2) #print string 2 times
# Out:
# Hello World!Hello World!

# %%
print (str + "TEST") #prints concatenated string
# Out:
# Hello World!TEST

# %%
print(str[4:7])
# Out:
# o W

# %%
#PYTHON LIST

# %%
list = [ 'abcd',786,'john',70.2]
tinylist =[123, 'john']

# %%
print(list) #print complete list"
# Out:
# ['abcd', 786, 'john', 70.2]

# %%
print(list[0]) #prints 1st element of the list
# Out:
# abcd

# %%
print(list[1:3]) #prints elemts from 2nd to 3rd
# Out:
# [786, 'john']

# %%
print(list[2:]) #prints list starting from 3rd elemts
# Out:
# ['john', 70.2]

# %%
print(tinylist*2) #prints list 2 times
# Out:
# [123, 'john', 123, 'john']

# %%
print (list+tinylist) #prints concatenated lists
# Out:
# ['abcd', 786, 'john', 70.2, 123, 'john']

# %%
#PYTHON TUPLES

# %%
tuple =('abcd', 786, 2,23, 'john', 70.2 )
tinytuple = ('john', 70.2)

# %%
print(tuple) #prints complete tuple
# Out:
# ('abcd', 786, 2, 23, 'john', 70.2)

# %%
print(tuple[0]) #prints 1st element os the tuple
# Out:
# abcd

# %%
print(tuple[1:3]) #prints elements from 2nd to 3rd
# Out:
# (786, 2)

# %%
print(tuple[2:]) #prints elemts from 2nd
# Out:
# (2, 23, 'john', 70.2)

# %%
print(tuple + tinytuple) #prints concatenated tuples
# Out:
# ('abcd', 786, 2, 23, 'john', 70.2, 'john', 70.2)

# %%
tuple[2]=1000 # tuple cannot be edited so we get type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_80/4194835380.py in <module>
# ----> 1 tuple[2]=1000 # tuple cannot be edited so we get type error
#
# TypeError: 'tuple' object does not support item assignment

# %%
list
# Out:
# ['abcd', 786, 'john', 70.2]

# %%
list[3]=1000

# %%
list
# Out:
# ['abcd', 786, 'john', 1000]

# %%
#DICTIONARY

# %%
dict={}
dict['one']="this is one"
dict[2]="this is two"
tinydict={'name': 'john','code':6734, 'dept':'sales'}
print (dict['one']) # Prints value for 'one' key
print (dict[2]) # Prints value for 2 key
print (tinydict) # Prints complete dictionary
print (tinydict.keys()) # Prints all the keys
print (tinydict.values()) # Prints all the values
# Out:
# this is one
# this is two
# {'name': 'john', 'code': 6734, 'dept': 'sales'}
# dict_keys(['name', 'code', 'dept'])
# dict_values(['john', 6734, 'sales'])
